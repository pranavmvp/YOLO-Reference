# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/My Drive/YOLOv3_Test'
# Out:
# backup	custom_data  custom_data.zip  weights

# %%
# !unzip '/content/drive/My Drive/YOLOv3_Test/custom_data.zip' -d '/content/drive/My Drive/YOLOv3_Test'
# Out:
# Archive:  /content/drive/My Drive/YOLOv3_Test/custom_data.zip
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/1.jpeg
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/1.txt
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/2.jpeg
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/2.txt
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/3.jpeg
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/3.txt
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/5.jpeg
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/5.txt
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/6.jpeg
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/6.txt
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/7.jpeg
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/7.txt
#   inflating: /content/drive/My Drive/YOLOv3_Test/custom_data/8.jpeg
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/YOLOv3_Test/darknet'
# Out:
# Cloning into '/content/drive/My Drive/YOLOv3_Test/darknet'...
# remote: Enumerating objects: 15038, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 15038 (delta 12), reused 20 (delta 9), pack-reused 15002
# Receiving objects: 100% (15038/15038), 13.44 MiB | 8.30 MiB/s, done.
# Resolving deltas: 100% (10211/10211), done.
# Checking out files: 100% (2028/2028), done.

# %%
# %cd '/content/drive/My Drive/YOLOv3_Test/darknet/'
# Out:
# /content/drive/My Drive/YOLOv3_Test/darknet

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       net_cam_v4.sh
# build			data		       README.md
# build.ps1		image_yolov3.sh        results
# cfg			image_yolov4.sh        scripts
# cmake			include		       src
# CMakeLists.txt		json_mjpeg_streams.sh  vcpkg.json
# DarknetConfig.cmake.in	LICENSE		       video_yolov3.sh
# darknet_images.py	Makefile	       video_yolov4.sh
# darknet.py		net_cam_v3.sh

# %%
# Change Makefile at this point

'''
GPU = 1
CUDNN = 1
OPENCV = 1

'''
# Out:
# '\nGPU = 1\nCUDNN = 1\nOPENCV = 1\n\n'

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:935:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1136:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# %cd /content/drive/My Drive/YOLOv3_Test
# Out:
# /content/drive/My Drive/YOLOv3_Test

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# Download weights darknet53.conv74
# !wget https://pjreddie.com/media/files/darknet53.conv.74.

# %%
'''
Change yolov3.cfg

# Comment test parameters

# Training 
Batch and subdivisions as required

max_batches = No. of classes * 2000

Steps = 20% less than max_batches , 20% greater than max_batches

Search [yolo] - Change no. of classes
Preceding conv layer - Filters = (No. of classes + 5) * 3

'''
# Out:
# '\nChange yolov3.cfg\n\n# Comment test parameters\n\n# Training \nBatch and subdivisions as required\n\nmax_batches = No. of classes * 2000\n\nSteps = 20% less than max_batches , 20% greater than max_batches\n\nSearch [yolo] - Change no. of classes\nPreceding conv layer - Filters = (No. of classes + 5) * 3\n\n'

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg weights/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 14875, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.896647), count: 1, class_loss = 0.000020, iou_loss = 0.024089, total_loss = 0.024109
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# ...
